# %%
import numpy as np
import pandas as pd
import torch

# %%
from transformers import AutoModelForCausalLM

# %%
model = AutoModelForCausalLM.from_pretrained("openai/gpt-oss-120b")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2098, in _LazyModule.__getattr__(self, name)
#    2097 try:
# -> 2098     module = self._get_module(self._class_to_module[name])
#    2099     value = getattr(module, name)
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2288, in _LazyModule._get_module(self, module_name)
#    2287 except Exception as e:
# -> 2288     raise e
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2286, in _LazyModule._get_module(self, module_name)
#    2285 try:
# -> 2286     return importlib.import_module("." + module_name, self.__name__)
#    2287 except Exception as e:
#
# File /opt/tcnjhpc/Python-3.10.11/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/gpt_oss/modeling_gpt_oss.py:32
#      31 from ...masking_utils import create_causal_mask, create_sliding_window_causal_mask
# ---> 32 from ...modeling_layers import (
#      33     GenericForSequenceClassification,
#      34     GenericForTokenClassification,
#      35     GradientCheckpointingLayer,
#      36 )
#      37 from ...modeling_outputs import MoeCausalLMOutputWithPast, MoeModelOutputWithPast
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_layers.py:27
#      26 from .models.auto import AutoModel
# ---> 27 from .processing_utils import Unpack
#      28 from .utils import TransformersKwargs, auto_docstring, can_return_tuple, logging
#
# File ~/.local/lib/python3.10/site-packages/transformers/processing_utils.py:38
#      37 from .feature_extraction_utils import BatchFeature
# ---> 38 from .image_utils import ChannelDimension, ImageInput, is_vision_available
#      39 from .tokenization_utils_base import (
#      40     PaddingStrategy,
#      41     PreTokenizedInput,
#    (...)
#      44     TruncationStrategy,
#      45 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/image_utils.py:53
#      52 if is_torchvision_available():
# ---> 53     from torchvision.transforms import InterpolationMode
#      55     pil_torch_interpolation_mapping = {
#      56         PILImageResampling.NEAREST: InterpolationMode.NEAREST_EXACT,
#      57         PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      61         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      62     }
#
# File ~/.local/lib/python3.10/site-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~/.local/lib/python3.10/site-packages/torchvision/_meta_registrations.py:164
#     160     return grad.new_empty((batch_size, channels, height, width))
#     163 @torch.library.register_fake("torchvision::nms")
# --> 164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#
# File ~/.local/lib/python3.10/site-packages/torch/library.py:1073, in register_fake.<locals>.register(func)
#    1072     use_lib = lib
# -> 1073 use_lib._register_fake(
#    1074     op_name, func, _stacklevel=stacklevel + 1, allow_override=allow_override
#    1075 )
#    1076 return func
#
# File ~/.local/lib/python3.10/site-packages/torch/library.py:203, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     201     func_to_register = fn
# --> 203 handle = entry.fake_impl.register(
#     204     func_to_register, source, lib=self, allow_override=allow_override
#     205 )
#     206 self._registration_handles.append(handle)
#
# File ~/.local/lib/python3.10/site-packages/torch/_library/fake_impl.py:50, in FakeImplHolder.register(self, func, source, lib, allow_override)
#      45     raise RuntimeError(
#      46         f"register_fake(...): the operator {self.qualname} "
#      47         f"already has an fake impl registered at "
#      48         f"{self.kernel.source}."
#      49     )
# ---> 50 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      51     raise RuntimeError(
#      52         f"register_fake(...): the operator {self.qualname} "
#      53         f"already has an DispatchKey::Meta implementation via a "
#    (...)
#      56         f"register_fake."
#      57     )
#
# RuntimeError: operator torchvision::nms does not exist
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = AutoModelForCausalLM.from_pretrained("openai/gpt-oss-120b")
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:369, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     365     return model_class.from_pretrained(
#     366         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     367     )
#     368 elif type(config) in cls._model_mapping:
# --> 369     model_class = _get_model_class(config, cls._model_mapping)
#     370     if model_class.config_class == config.sub_configs.get("text_config", None):
#     371         config = config.get_text_config()
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:178, in _get_model_class(config, model_mapping)
#     177 def _get_model_class(config, model_mapping):
# --> 178     supported_models = model_mapping[type(config)]
#     179     if not isinstance(supported_models, (list, tuple)):
#     180         return supported_models
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:570, in _LazyAutoMapping.__getitem__(self, key)
#     568 if model_type in self._model_mapping:
#     569     model_name = self._model_mapping[model_type]
# --> 570     return self._load_attr_from_module(model_type, model_name)
#     572 # Maybe there was several model types associated with this config.
#     573 model_types = [k for k, v in self._config_mapping.items() if v == key.__name__]
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:584, in _LazyAutoMapping._load_attr_from_module(self, model_type, attr)
#     582 if module_name not in self._modules:
#     583     self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 584 return getattribute_from_module(self._modules[module_name], attr)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:496, in getattribute_from_module(module, attr)
#     494 if isinstance(attr, tuple):
#     495     return tuple(getattribute_from_module(module, a) for a in attr)
# --> 496 if hasattr(module, attr):
#     497     return getattr(module, attr)
#     498 # Some of the mappings have entries model_type -> object of another model type. In that case we try to grab the
#     499 # object at the top level.
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:2182, in _LazyModule.__getattr__(self, name)
#    2178                     raise ModuleNotFoundError(
#    2179                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2180                     ) from e
#    2181         else:
# -> 2182             raise ModuleNotFoundError(
#    2183                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2184             ) from e
#    2186 elif name in self._modules:
#    2187     try:
#
# ModuleNotFoundError: Could not import module 'GptOssForCausalLM'. Are this object's requirements defined correctly?
